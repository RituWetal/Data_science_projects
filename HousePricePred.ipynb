# %% [markdown]
# ## Problem Statement
#
# **Task 1:-** Prepare a complete data analysis report on the given data.
#
# **Task 2:-** Create a predictive model which will help the bank marketing team to know which customer will buy the product.
#
# **Task3:-** Suggestions to the Bank market team to make  customers  buy the product.
#
# ## Information of datasets
# Ask a home buyer to describe their dream house, and they probably won't begin with the height of the basement ceiling or the proximity to an east-west railroad. But this playground competition's dataset proves that much more influences price negotiations than the number of bedrooms or a white-picket fence.
# With 79 explanatory variables describing (almost) every aspect of residential homes in Ames, Iowa, this competition challenges you to predict the final price of each home.
#
# **Attribute Information:**
# ●	SalePrice - the property's sale price in dollars. This is the target variable that you're trying to predict.
# ●	MSSubClass: The building class
# ●	MSZoning: The general zoning classification
# ●	LotFrontage: Linear feet of street connected to property
# ●	LotArea: Lot size in square feet
# ●	Street: Type of road access
# ●	Alley: Type of alley access
# ●	LotShape: General shape of property
# ●	LandContour: Flatness of the property
# ●	Utilities: Type of utilities available
# ●	LotConfig: Lot configuration
# ●	LandSlope: Slope of property
# ●	Neighborhood: Physical locations within Ames city limits
# ●	Condition1: Proximity to main road or railroad
# ●	Condition2: Proximity to main road or railroad (if a second is present)
# ●	BldgType: Type of dwelling
# ●	HouseStyle: Style of dwelling
# ●	OverallQual: Overall material and finish quality
# ●	OverallCond: Overall condition rating
# ●	YearBuilt: Original construction date
# ●	YearRemodAdd: Remodel date
# ●	RoofStyle: Type of roof
# ●	RoofMatl: Roof material
# ●	Exterior1st: Exterior covering on house
# ●	Exterior2nd: Exterior covering on house (if more than one material)
# ●	MasVnrType: Masonry veneer type
# ●	MasVnrArea: Masonry veneer area in square feet
# ●	ExterQual: Exterior material quality
# ●	ExterCond: Present condition of the material on the exterior
# ●	Foundation: Type of foundation
# ●	BsmtQual: Height of the basement
# ●	BsmtCond: General condition of the basement
# ●	BsmtExposure: Walkout or garden level basement walls
# ●	BsmtFinType1: Quality of basement finished area
# ●	BsmtFinSF1: Type 1 finished square feet
# ●	BsmtFinType2: Quality of second finished area (if present)
# ●	BsmtFinSF2: Type 2 finished square feet
# ●	BsmtUnfSF: Unfinished square feet of basement area
# ●	TotalBsmtSF: Total square feet of basement area
# ●	Heating: Type of heating
# ●	HeatingQC: Heating quality and condition
# ●	CentralAir: Central air conditioning
# ●	Electrical: Electrical system
# ●	1stFlrSF: First Floor square feet
# ●	2ndFlrSF: Second floor square feet
# ●	LowQualFinSF: Low quality finished square feet (all floors)
# ●	GrLivArea: Above grade (ground) living area square feet
# ●	BsmtFullBath: Basement full bathrooms
# ●	BsmtHalfBath: Basement half bathrooms
# ●	FullBath: Full bathrooms above grade
# ●	HalfBath: Half baths above grade
# ●	Bedroom: Number of bedrooms above basement level
# ●	Kitchen: Number of kitchens
# ●	KitchenQual: Kitchen quality
# ●	TotRmsAbvGrd: Total rooms above grade (does not include bathrooms)
# ●	Functional: Home functionality rating
# ●	Fireplaces: Number of fireplaces
# ●	FireplaceQu: Fireplace quality
# ●	GarageType: Garage location
# ●	GarageYrBlt: Year garage was built
# ●	GarageFinish: Interior finish of the garage
# ●	GarageCars: Size of garage in car capacity
# ●	GarageArea: Size of garage in square feet
# ●	GarageQual: Garage quality
# ●	GarageCond: Garage condition
# ●	PavedDrive: Paved driveway
# ●	WoodDeckSF: Wood deck area in square feet
# ●	OpenPorchSF: Open porch area in square feet
# ●	EnclosedPorch: Enclosed porch area in square feet
# ●	3SsnPorch: Three season porch area in square feet
# ●	ScreenPorch: Screen porch area in square feet
# ●	PoolArea: Pool area in square feet
# ●	PoolQC: Pool quality
# ●	Fence: Fence quality
# ●	MiscFeature: Miscellaneous feature not covered in other categories
# ●	MiscVal: $Value of miscellaneous feature
# ●	MoSold: Month Sold
# ●	YrSold: Year Sold
# ●	SaleType: Type of sale
# ●	SaleCondition: Condition of sale

# %%
## import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
## Load the dataset
data=pd.read_csv('data.csv')

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
## To show the all columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ## we get the brief information od the Dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %% [raw]
# ## Most Null Value Feature
# Alley
# FireplaceQu
# PoolQC
# Fence
# MiscFeature

# %%
int_features= data.select_dtypes(include=['int64']).columns
print('Total number of integer features :',int_features.shape[0])
print('Integer feature names :',int_features.tolist())
# Out:
# Total number of integer features : 35
# Integer feature names : ['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %%
float_features= data.select_dtypes(include=['float64']).columns
print('Total number of floating features :',float_features.shape[0])
print('floating feature names :',float_features.tolist())
# Out:
# Total number of floating features : 3
# floating feature names : ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
cat_features= data.select_dtypes(include=['object']).columns
print('Total number of categorical features :',cat_features.shape[0])
print('categorical feature names :',cat_features.tolist())
# Out:
# Total number of categorical features : 43
# categorical feature names : ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %% [markdown]
# ## Get the Statistical information of Numerical Features

# %%
data.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
data.describe().shape
# Out:
# (8, 38)

# %% [markdown]
# ## Handling missing value
# ## Visulise null/missing value

# %%
# Show the null values using heatmap
plt.figure(figsize=(16,9))
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ## Get the null value percentage for every feature

# %%
## set index as Id column
data= data.set_index('Id')

# %%
null_count=data.isnull().sum()
null_count
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType        872
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# ...

# %%
null_percent=data.isnull().sum()/data.shape[0]*100
null_percent
# Out:
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
# Street            0.000000
# Alley            93.767123
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.000000
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.000000
# Exterior2nd       0.000000
# MasVnrType       59.726027
# MasVnrArea        0.547945
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.534247
# BsmtCond          2.534247
# BsmtExposure      2.602740
# BsmtFinType1      2.534247
# BsmtFinSF1        0.000000
# ...

# %% [markdown]
# ## Drop Columns/Features
# ***As per observation, we will not drop any feature from dataset***

# %%
''' As per domain knowledge we will not drop those features,
insted None value we will add constant value "NA" '''
miss_value_50_perc=null_percent[null_percent>50]
miss_value_50_perc
# Out:
# Alley          93.767123
# MasVnrType     59.726027
# PoolQC         99.520548
# Fence          80.753425
# MiscFeature    96.301370
# dtype: float64

# %%
data['Alley'].value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %%
''' As per domain knowledge we will not drop FireplaceQu features,
insted None value we will add constant value "NA" '''
miss_value_20_50_perc=null_percent[(null_percent>20) & (null_percent<51)]
miss_value_20_50_perc
# Out:
# FireplaceQu    47.260274
# dtype: float64

# %%
miss_value_5_20_perc=null_percent[(null_percent>5) & (null_percent<21)]
miss_value_5_20_perc
# Out:
# LotFrontage     17.739726
# GarageType       5.547945
# GarageYrBlt      5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# dtype: float64

# %%
data['LotFrontage'].value_counts().head()
# Out:
# LotFrontage
# 60.0    143
# 70.0     70
# 80.0     69
# 50.0     57
# 75.0     53
# Name: count, dtype: int64

# %%
sns.heatmap(data[miss_value_5_20_perc.keys()].isnull())
# Out:
# <Axes: ylabel='Id'>

# %% [markdown]
# ## Missing Value imputation

# %%
missing_Value_feat=null_percent[null_percent>0]
print('Total missing values features =',len(missing_Value_feat))
# Out:
# Total missing values features = 19

# %%
missing_Value_feat
# Out:
# LotFrontage     17.739726
# Alley           93.767123
# MasVnrType      59.726027
# MasVnrArea       0.547945
# BsmtQual         2.534247
# BsmtCond         2.534247
# BsmtExposure     2.602740
# BsmtFinType1     2.534247
# BsmtFinType2     2.602740
# Electrical       0.068493
# FireplaceQu     47.260274
# GarageType       5.547945
# GarageYrBlt      5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# PoolQC          99.520548
# Fence           80.753425
# MiscFeature     96.301370
# dtype: float64

# %%
cat_na_feat = missing_Value_feat[missing_Value_feat.keys().isin(cat_features)]
print('Total number of categorical missing features = ',len(cat_na_feat))
cat_na_feat
# Out:
# Total number of categorical missing features =  16
# Alley           93.767123
# MasVnrType      59.726027
# BsmtQual         2.534247
# BsmtCond         2.534247
# BsmtExposure     2.602740
# BsmtFinType1     2.534247
# BsmtFinType2     2.602740
# Electrical       0.068493
# FireplaceQu     47.260274
# GarageType       5.547945
# GarageFinish     5.547945
# GarageQual       5.547945
# GarageCond       5.547945
# PoolQC          99.520548
# Fence           80.753425
# MiscFeature     96.301370
# dtype: float64

# %%
int_na_feat = missing_Value_feat[missing_Value_feat.keys().isin(int_features)]
print('Total number of integer missing features = ',len(int_na_feat))
int_na_feat
# Out:
# Total number of integer missing features =  0
# Series([], dtype: float64)

# %%
float_na_feat = missing_Value_feat[missing_Value_feat.keys().isin(float_features)]
print('Total number of float missing features = ',len(float_na_feat))
float_na_feat
# Out:
# Total number of float missing features =  3
# LotFrontage    17.739726
# MasVnrArea      0.547945
# GarageYrBlt     5.547945
# dtype: float64

# %% [markdown]
# ## handling Electrical = 0.068493

# %%
data['Electrical'].value_counts()
# Out:
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: count, dtype: int64

# %%
sns.histplot(data["Electrical"])
# Out:
# <Axes: xlabel='Electrical', ylabel='Count'>

# %%
## backup of original data
data_mvi=data.copy()
data_mvi.shape
# Out:
# (1460, 80)

# %%
electrical_mode = data["Electrical"].mode()[0]
data_mvi["Electrical"].replace(np.nan, electrical_mode, inplace=True)
data_mvi["Electrical"].isnull().sum()
# Out:
# 0

# %%
def oldnewhistplot(data,data_new,feature):
    plt.subplot(121)
    sns.histplot(data[feature])
    plt.title('Old data distribution')
    plt.subplot(122)
    sns.histplot(data_new[feature])
    plt.title('New data distribution')

# %%
oldnewhistplot(data,data_mvi,'Electrical')

# %% [markdown]
# ## Handling Alley = 93.767123

# %%
data_mvi['Alley'].value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %%
alley_const='NA'
data_mvi['Alley'].replace(np.nan,alley_const,inplace=True)
data_mvi['Alley'].isnull().sum()
# Out:
# 0

# %%
oldnewhistplot(data,data_mvi,'Alley')

# %% [markdown]
# ## Handling LotFrontage = 17.739726

# %%
def distplot(data,figsize=(16,5)):
    plt.figure(figsize=figsize)
    plt.subplot(121)
    sns.distplot(data)
    #plt.subplot(122)
    #sns.boxplot(data=data)

# %%
distplot(data['LotFrontage'])

# %%
lotfrontage_mean=data['LotFrontage'].mean()
data_mvi['LotFrontage'].replace(np.nan,lotfrontage_mean,inplace=True)
data_mvi['LotFrontage'].isnull().sum()
# Out:
# 0

# %%
def oldnewdistplot(data,data_new,feature,figsize=(16,10)):
    plt.figure(figsize=figsize)
    plt.subplot(221)
    sns.distplot(data[feature])
    plt.title('Old data distribution')
    plt.subplot(222)
    sns.distplot(data_new[feature])
    plt.title('New data distribution')

# %%
oldnewdistplot(data,data_mvi,'LotFrontage',figsize=(16,10))

# %% [markdown]
# ## handling MasVnrType = 59.726027, MasVnrArea = 0.547945

# %%
sns.heatmap(data[['MasVnrType','MasVnrArea']].isnull())
# Out:
# <Axes: ylabel='Id'>

# %%
data[data[['MasVnrType','MasVnrArea']].isnull().any(axis=1)]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 6             50       RL         85.0    14115   Pave   NaN      IR1
# 9             50       RM         51.0     6120   Pave   NaN      Reg
# 10           190       RL         50.0     7420   Pave   NaN      Reg
# 11            20       RL         70.0    11200   Pave   NaN      Reg
# 13            20       RL          NaN    12968   Pave   NaN      IR2
# 16            45       RM         51.0     6120   Pave   NaN      Reg
# 18            90       RL         72.0    10791   Pave   NaN      Reg
# 19            20       RL         66.0    13695   Pave   NaN      Reg
# 20            20       RL         70.0     7560   Pave   NaN      Reg
# 22            45       RM         57.0     7449   Pave  Grvl      Reg
# ...

# %%
data['MasVnrType'].value_counts()
# Out:
# MasVnrType
# BrkFace    445
# Stone      128
# BrkCmn      15
# Name: count, dtype: int64

# %%
alley_const='NA'
data_mvi['MasVnrType'].replace(np.nan,alley_const,inplace=True)
data_mvi['MasVnrType'].isnull().sum()
# Out:
# 0

# %%
oldnewhistplot(data,data_mvi,'MasVnrType')

# %%
distplot(data['MasVnrArea'])

# %%
masdvnrarea_const=0
data_mvi['MasVnrArea'].replace(np.nan,masdvnrarea_const,inplace=True)
data_mvi['MasVnrArea'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ## handing
# #### Categorical feature
# BsmtQual = 2.534247,
# BsmtCond = 2.534247,
# BsmtExposure = 2.602740,
# BsmtFinType1 = 2.534247,
# BsmtFinType2 = 2.602740

# %%
cat_bsmt_feat=['BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2']

# %%
sns.heatmap(data[cat_bsmt_feat].isnull())
# Out:
# <Axes: ylabel='Id'>

# %%
for feat in cat_bsmt_feat:
    print('Value count of feat :', data[feat].value_counts())
# Out:
# Value count of feat : BsmtQual
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: count, dtype: int64
# Value count of feat : BsmtCond
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: count, dtype: int64
# Value count of feat : BsmtExposure
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: count, dtype: int64
# Value count of feat : BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: count, dtype: int64
# Value count of feat : BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: count, dtype: int64

# %%
bsmt_const='NA'
for feat in cat_bsmt_feat:
    data_mvi[feat].replace(np.nan,bsmt_const,inplace=True)

# %%
data_mvi[cat_bsmt_feat].isnull().sum()
# Out:
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# dtype: int64

# %% [markdown]
# ## Handling remaing categorial feature
# FireplaceQu  =   47.260274 - NA value
# PoolQC       =  99.520548 - NA value
# Fence        =  80.753425 - NA value
# MiscFeature  =  96.301370 - NA value

# %%
other_cat_feat=['FireplaceQu',
'PoolQC',
'Fence', 
'MiscFeature']

for feat in other_cat_feat:
    print('Value count of feat :', data[feat].value_counts())
# Out:
# Value count of feat : FireplaceQu
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: count, dtype: int64
# Value count of feat : PoolQC
# Gd    3
# Ex    2
# Fa    2
# Name: count, dtype: int64
# Value count of feat : Fence
# MnPrv    157
# GdPrv     59
# GdWo      54
# MnWw      11
# Name: count, dtype: int64
# Value count of feat : MiscFeature
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: count, dtype: int64

# %%
fpfm_const='NA'
for feat in other_cat_feat:
    data_mvi[feat].replace(np.nan,fpfm_const,inplace=True)

# %%
data_mvi[other_cat_feat].isnull().sum()
# Out:
# FireplaceQu    0
# PoolQC         0
# Fence          0
# MiscFeature    0
# dtype: int64

# %% [markdown]
# ## Handing Garage Features
# #### categorical
# GarageType     = 5.547945 - NA
# GarageFinish   = 5.547945 - NA
# GarageQual     = 5.547945 - NA
# GarageCond     = 5.547945 - NA
# #### Numerica
# GarageYrBlt   =  5.547945 - 0

# %%
cat_garage_feat = ['GarageType','GarageFinish','GarageQual','GarageCond']
num_garage_feat = ['GarageYrBlt']
data_garage = data[cat_garage_feat+num_garage_feat]
data_garage[data_garage.isnull().any(axis=1)]
# Out:
#      GarageType GarageFinish GarageQual GarageCond  GarageYrBlt
# Id
# 40          NaN          NaN        NaN        NaN          NaN
# 49          NaN          NaN        NaN        NaN          NaN
# 79          NaN          NaN        NaN        NaN          NaN
# 89          NaN          NaN        NaN        NaN          NaN
# 90          NaN          NaN        NaN        NaN          NaN
# 100         NaN          NaN        NaN        NaN          NaN
# 109         NaN          NaN        NaN        NaN          NaN
# 126         NaN          NaN        NaN        NaN          NaN
# 128         NaN          NaN        NaN        NaN          NaN
# 141         NaN          NaN        NaN        NaN          NaN
# 149         NaN          NaN        NaN        NaN          NaN
# 156         NaN          NaN        NaN        NaN          NaN
# 164         NaN          NaN        NaN        NaN          NaN
# 166         NaN          NaN        NaN        NaN          NaN
# ...

# %%
garage_const='NA'
for feat in cat_garage_feat:
    data_mvi[feat].replace(np.nan,garage_const,inplace=True)
    
data_mvi[cat_garage_feat].isnull().sum()
# Out:
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# dtype: int64

# %%
garageyrblt_const=0
data_mvi['GarageYrBlt'].replace(np.nan,garageyrblt_const,inplace=True)
data_mvi['GarageYrBlt'].isnull().sum()
# Out:
# 0

# %%
data_mvi.isnull().any(axis=1).sum()
# Out:
# 0

# %% [markdown]
# ## We handle all missing values present in our data set

# %% [markdown]
# ## Feature transformation
# ## Convert numerical  to categorical

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          91 non-null     object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   object
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %%
for_num_conv=['MSSubClass','YearBuilt','YearRemodAdd','GarageYrBlt','MoSold','YrSold']
for feat in for_num_conv:
    print(f'{feat}:data type = {data_mvi[feat].dtype}')
# Out:
# MSSubClass:data type = int64
# YearBuilt:data type = int64
# YearRemodAdd:data type = int64
# GarageYrBlt:data type = float64
# MoSold:data type = int64
# YrSold:data type = int64

# %%
data_mvi[for_num_conv].head()
# Out:
#     MSSubClass  YearBuilt  YearRemodAdd  GarageYrBlt  MoSold  YrSold
# Id
# 1           60       2003          2003       2003.0       2    2008
# 2           20       1976          1976       1976.0       5    2007
# 3           60       2001          2002       2001.0       9    2008
# 4           70       1915          1970       1998.0       2    2006
# 5           60       2000          2000       2000.0      12    2008

# %%
data_mvi['MoSold'].unique()
# Out:
# array([ 2,  5,  9, 12, 10,  8, 11,  4,  1,  7,  3,  6], dtype=int64)

# %%
import calendar
calendar.month_abbr[12]
# Out:
# 'Dec'

# %%
data_mvi['MoSold']=data_mvi['MoSold'].apply(lambda x : calendar.month_abbr[x])
data_mvi['MoSold'].unique()
# Out:
# array(['Feb', 'May', 'Sep', 'Dec', 'Oct', 'Aug', 'Nov', 'Apr', 'Jan',
#        'Jul', 'Mar', 'Jun'], dtype=object)

# %%
for feat in for_num_conv:
    data_mvi[feat]=data_mvi[feat].astype(str)

# %%
for feat in for_num_conv:
    print(f'{feat}:data type = {data_mvi[feat].dtype}')
# Out:
# MSSubClass:data type = object
# YearBuilt:data type = object
# YearRemodAdd:data type = object
# GarageYrBlt:data type = object
# MoSold:data type = object
# YrSold:data type = object

# %% [markdown]
# ## Convert Categorical Features into Numerical Features
# ## Ordinal Encoding

# %%
ordinal_end_var = ['ExterQual','ExterCond','BsmtQual','BsmtCond','BsmtExposure',
                   'BsmtFinType1','BsmtFinSF1','BsmtFinType2','HeatingQC','KitchenQual',
                   'FireplaceQu','GarageQual','GarageCond','PoolQC','Functional',
                   'GarageFinish','PavedDrive','Utilities']
print('Total number of features to convert ordinal numerical format:', len(ordinal_end_var))
# Out:
# Total number of features to convert ordinal numerical format: 18

# %%
from pandas.api.types import CategoricalDtype

# %%
data_mvi['ExterQual'].value_counts()
# Out:
# ExterQual
# TA    906
# Gd    488
# Ex     52
# Fa     14
# Name: count, dtype: int64

# %%
data_mvi['ExterQual']=data_mvi['ExterQual'].astype(CategoricalDtype(categories=['Po','Fa','TA','Gd','Ex'],ordered=True)).cat.codes

# %%
data_mvi['ExterQual'].value_counts()
# Out:
# ExterQual
# 2    906
# 3    488
# 4     52
# 1     14
# Name: count, dtype: int64

# %%
data_mvi['BsmtExposure'].value_counts()
# Out:
# BsmtExposure
# No    953
# Av    221
# Gd    134
# Mn    114
# NA     38
# Name: count, dtype: int64

# %%
data_mvi['BsmtExposure']=data_mvi['BsmtExposure'].astype(CategoricalDtype(categories=['No','NA','Mn','Av','Gd'],ordered=True)).cat.codes

# %%
data_mvi['BsmtExposure'].value_counts()
# Out:
# BsmtExposure
# 0    953
# 3    221
# 4    134
# 2    114
# 1     38
# Name: count, dtype: int64

# %%
data_mvi['ExterCond']=data_mvi['ExterCond'].astype(CategoricalDtype(categories=['Po','Fa','TA','Gd','Ex'],ordered=True)).cat.codes
data_mvi['BsmtQual']=data_mvi['BsmtQual'].astype(CategoricalDtype(categories=['NA','Po','Fa','TA','Gd','Ex'],ordered=True)).cat.codes
data_mvi['BsmtCond']=data_mvi['BsmtCond'].astype(CategoricalDtype(categories=['NA','Po','Fa','TA','Gd','Ex'],ordered=True)).cat.codes
data_mvi['BsmtFinType1']=data_mvi['BsmtFinType1'].astype(CategoricalDtype(categories=['NA','Unf','LwQ','Rec','BLQ','ALQ','GLQ'],ordered=True)).cat.codes
data_mvi['BsmtFinType2']=data_mvi['BsmtFinType2'].astype(CategoricalDtype(categories=['NA','Unf','LwQ','Rec','BLQ','ALQ','GLQ'],ordered=True)).cat.codes
data_mvi['HeatingQC']=data_mvi['HeatingQC'].astype(CategoricalDtype(categories=['Po','Fa','TA','Gd','Ex'],ordered=True)).cat.codes
data_mvi['KitchenQual']=data_mvi['KitchenQual'].astype(CategoricalDtype(categories=['Po','Fa','TA','Gd','Ex'],ordered=True)).cat.codes
data_mvi['FireplaceQu']=data_mvi['FireplaceQu'].astype(CategoricalDtype(categories=['NA','Po','Fa','TA','Gd','Ex'],ordered=True)).cat.codes
data_mvi['GarageQual']=data_mvi['GarageQual'].astype(CategoricalDtype(categories=['NA','Po','Fa','TA','Gd','Ex'],ordered=True)).cat.codes
data_mvi['GarageCond']=data_mvi['GarageCond'].astype(CategoricalDtype(categories=['NA','Po','Fa','TA','Gd','Ex'],ordered=True)).cat.codes
data_mvi['PoolQC']=data_mvi['PoolQC'].astype(CategoricalDtype(categories=['NA','Po','Fa','TA','Gd','Ex'],ordered=True)).cat.codes
data_mvi['Functional']=data_mvi['Functional'].astype(CategoricalDtype(categories=['Sal','Sev','Maj2','Maj1','Mod','Min2','Min1','Typ'],ordered=True)).cat.codes
data_mvi['GarageFinish']=data_mvi['GarageFinish'].astype(CategoricalDtype(categories=['NA','Unf','RFn','Fin'],ordered=True)).cat.codes
data_mvi['PavedDrive']=data_mvi['PavedDrive'].astype(CategoricalDtype(categories=['N','P','Y'],ordered=True)).cat.codes
data_mvi['Utilities']=data_mvi['Utilities'].astype(CategoricalDtype(categories=['ELO','NASeWa','NASeWr','AllPub'],ordered=True)).cat.codes

# %%
data_mvi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   object
#  1   MSZoning       1460 non-null   object
#  2   LotFrontage    1460 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   object
#  5   Alley          1460 non-null   object
#  6   LotShape       1460 non-null   object
#  7   LandContour    1460 non-null   object
#  8   Utilities      1460 non-null   int8
#  9   LotConfig      1460 non-null   object
#  10  LandSlope      1460 non-null   object
#  11  Neighborhood   1460 non-null   object
#  12  Condition1     1460 non-null   object
#  13  Condition2     1460 non-null   object
#  14  BldgType       1460 non-null   object
#  15  HouseStyle     1460 non-null   object
#  16  OverallQual    1460 non-null   int64
# ...

# %% [markdown]
# ## One Hot Encoding for Nominal Categorical Data

# %%
data_encod = data_mvi.copy()

object_features=data_encod.select_dtypes(include='object').columns.tolist()
print('total object data type features : ',len(object_features))
print('Features : \n',object_features)
# Out:
# total object data type features :  32
# Features :
#  ['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation', 'Heating', 'CentralAir', 'Electrical', 'GarageType', 'GarageYrBlt', 'Fence', 'MiscFeature', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition']

# %%
data_encod[object_features].head(2)
# Out:
#    MSSubClass MSZoning Street Alley LotShape LandContour LotConfig LandSlope  \
# Id
# 1          60       RL   Pave    NA      Reg         Lvl    Inside       Gtl
# 2          20       RL   Pave    NA      Reg         Lvl       FR2       Gtl
#
#    Neighborhood Condition1 Condition2 BldgType HouseStyle YearBuilt  \
# Id
# 1       CollgCr       Norm       Norm     1Fam     2Story      2003
# 2       Veenker      Feedr       Norm     1Fam     1Story      1976
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 2          1976     Gable  CompShg     MetalSd     MetalSd         NA
#
#    Foundation Heating CentralAir Electrical GarageType GarageYrBlt Fence  \
# Id
# 1       PConc    GasA          Y      SBrkr     Attchd      2003.0    NA
# 2      CBlock    GasA          Y      SBrkr     Attchd      1976.0    NA
#
#    MiscFeature MoSold YrSold SaleType SaleCondition
# Id
# ...

# %%
print('Shape of DF before encoding : ',data_encod.shape)
data_encod=pd.get_dummies(data_encod, 
                         columns=object_features,
                         prefix=object_features,
                         drop_first=True, 
                          dtype=int)
print('Shape of DF after encoding : ',data_encod.shape)
# Out:
# Shape of DF before encoding :  (1460, 80)
# Shape of DF after encoding :  (1460, 500)

# %%
data_encod.head(2)
# Out:
#     LotFrontage  LotArea  Utilities  OverallQual  OverallCond  MasVnrArea  \
# Id
# 1          65.0     8450          3            7            5       196.0
# 2          80.0     9600          3            6            8         0.0
#
#     ExterQual  ExterCond  BsmtQual  BsmtCond  BsmtExposure  BsmtFinType1  \
# Id
# 1           3          2         4         3             0             6
# 2           2          2         4         3             4             5
#
#     BsmtFinSF1  BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  HeatingQC  \
# Id
# 1          706             1           0        150          856          4
# 2          978             1           0        284         1262          4
#
#     1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1        856       854             0       1710             1             0
# 2       1262         0             0       1262             0             1
#
# ...

# %%
data_encod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1460 entries, 1 to 1460
# Columns: 500 entries, LotFrontage to SaleCondition_Partial
# dtypes: float64(2), int32(452), int64(29), int8(17)
# memory usage: 2.9 MB

# %%
data_encod.select_dtypes(include='object').columns.tolist()
# Out:
# []

# %% [markdown]
# ## Split data for training and testing

# %%
data_encod.shape
# Out:
# (1460, 500)

# %%
len_train=data.shape[0]
len_train
# Out:
# 1460

# %%
X_train=data_encod[:len_train].drop('SalePrice', axis=1)
y_train = data_encod['SalePrice'][:len_train]

X_test = data_encod[:len_train].drop('SalePrice', axis=1)
y_test = data_encod['SalePrice'][len_train:]

print('Shape of X_train data :', X_train.shape)
print('Shape of y_train data :', y_train.shape)
print('Shape of X_test data :', X_test.shape)
print('Shape of y_test data :', y_test.shape)
# Out:
# Shape of X_train data : (1460, 499)
# Shape of y_train data : (1460,)
# Shape of X_test data : (1460, 499)
# Shape of y_test data : (0,)

# %%
## Creating independent and dependent variable
X = data_encod.drop('SalePrice', axis=1)#independent variable 
y = data_encod.SalePrice#dependent variable

# %%
X.shape
# Out:
# (1460, 499)

# %%
y.shape
# Out:
# (1460,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(X)
X=sc.transform(X)

# %%
X[:3,:]
# Out:
# array([[-0.22937175, -0.20714171,  0.02618016, ..., -0.11785113,
#          0.4676514 , -0.30599503],
#        [ 0.4519361 , -0.09188637,  0.02618016, ..., -0.11785113,
#          0.4676514 , -0.30599503],
#        [-0.09311018,  0.07347998,  0.02618016, ..., -0.11785113,
#          0.4676514 , -0.30599503]])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=9)

# %%
X_train.shape
# Out:
# (1095, 499)

# %%
y_train.shape
# Out:
# (1095,)

# %%
y_test.shape
# Out:
# (365,)

# %%
X_test.shape
# Out:
# (365, 499)

# %% [markdown]
# ## 1) LinearRegression

# %%
## Model creation
from sklearn.metrics import mean_absolute_error,r2_score
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)  ## training
# Out:
# LinearRegression()

# %%
## training accuracies
pred_train = lr.predict(X_train)
r2_score(y_train,pred_train)
# Out:
# 0.9429651018778262

# %%
## Testing accuracies
pred_test = lr.predict(X_test)
r2_score(y_test,pred_test)
# Out:
# -1.407634023098684e+24

# %% [markdown]
# ## 2) KNeighborsRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor
knr=KNeighborsRegressor()
knr.fit(X_train,y_train)
# Out:
# KNeighborsRegressor()

# %%
## training accuracies
pred_train = knr.predict(X_train)
r2_score(y_train,pred_train)
# Out:
# 0.709841629813061

# %%
## Testing accuracies
pred_test = knr.predict(X_test)
r2_score(y_test,pred_test)
# Out:
# 0.5252341461177075

# %% [markdown]
# ## 3) Support Vector Regressor

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(X_train,y_train)
# Out:
# SVR()

# %%
## training accuracies
pred_train = svr.predict(X_train)
r2_score(y_train,pred_train)
# Out:
# -0.06182131051851458

# %%
## Testing accuracies
pred_test = svr.predict(X_test)
r2_score(y_test,pred_test)
# Out:
# -0.09340340201964037

# %% [markdown]
# ## 4) DecisionTreeRegressor

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
dtr.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
## training accuracies
pred_train = dtr.predict(X_train)
r2_score(y_train,pred_train)
# Out:
# 1.0

# %%
## Testing accuracies
pred_test = dtr.predict(X_test)
r2_score(y_test,pred_test)
# Out:
# 0.7508748326724635

# %% [markdown]
# ## 5) GradientBoostingRegressor

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()
gbr.fit(X_train,y_train)
# Out:
# GradientBoostingRegressor()

# %%
## training accuracies
pred_train = gbr.predict(X_train)
r2_score(y_train,pred_train)
# Out:
# 0.9661692912115206

# %%
## Testing accuracies
pred_test = gbr.predict(X_test)
r2_score(y_test,pred_test)
# Out:
# 0.9148115534169543

# %% [markdown]
# ## 6) RandomForestRegressor

# %%
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
rfr.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
## training accuracies
pred_train = rfr.predict(X_train)
r2_score(y_train,pred_train)
# Out:
# 0.9761280114541145

# %%
## Testing accuracies
pred_test = rfr.predict(X_test)
r2_score(y_test,pred_test)
# Out:
# 0.8781899575475887

# %% [markdown]
# ## Model Comparison

# %%
dfr = pd.DataFrame()
dfr['Model'] = ['LinearRegression', 'KNeighborsRegressor', 'SVR','DecisionTreeRegressor','GradientBoostingRegressor','RandomForestRegressor']
dfr['r2_score'] = [-1.4, 0.52, -0.093, 0.75, 0.91,0.87]
dfr
# Out:
#                        Model  r2_score
# 0           LinearRegression    -1.400
# 1        KNeighborsRegressor     0.520
# 2                        SVR    -0.093
# 3      DecisionTreeRegressor     0.750
# 4  GradientBoostingRegressor     0.910
# 5      RandomForestRegressor     0.870

# %%
# coparision using graph
plt.figure(figsize=(15,5))
sns.set(style= 'whitegrid')
ax=sns.barplot(x='Model',y='r2_score',data=dfr)

# %% [markdown]
# ## Conclusion
# - GradientBoostingRegressor is the best model for prediction.
#
# ## Report on challenges faced:
# * Data preprocessing : Dataset have many columns, So preprocessing is lengthy.
# * Feature Selection : Choosing the right set of features that are relevant to the problemat hand can significantly impact the accuracy of a model.
# * Solution to problems we encountered while working on this project.
#
# ## Suggestion to bank marketing team:
# - Clearly define what the bank aims to achieve with the house price prediction model.
# - Collect high-quality, comprehensive data.This includes historical house prices, property features (e.g., size, number of bedrooms, location), economic indicators, and market trends.
# -  Identify and create features that significantly impact house prices, such as location-specific factors (neighborhood amenities, crime rates), property-specific features (age, type, size), and market conditions (interest rates, inflation).
# - Advanced Techniques: Use advanced feature engineering techniques, such as creating interaction terms or using domain knowledge to create meaningful variables.
# - Choose appropriate models for house price prediction.
# - Use cross-validation techniques to ensure the model’s robustness and avoid overfitting.
# - Use relevant evaluation metrics to assess the model’s performance. Metrics such as Mean Absolute Error (MAE), Mean Squared Error (MSE), Root Mean Squared Error (RMSE), and R² score are commonly used for regression tasks.
# - Compare the model's performance against benchmarks or existing methods to validate improvements.
# - Make usefull insights.
